# %% [markdown]
# # Módulo 4 — CNNs y patrones espaciales
#
# **Objetivo EVA Valle:** Matriz municipio×cultivo×año como 'imagen' para detectar patrones territoriales.
#
# 🚧 En construcción — se habilita al cerrar el módulo anterior.
