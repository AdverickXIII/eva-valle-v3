# %% [markdown]
# # Módulo 2 — RNN/LSTM/GRU
#
# **Objetivo EVA Valle:** Series por cultivo 2019-2025 → predicción 2026-2028. Meta: superar MAPE 4.2% de Alcalá.
#
# 🚧 En construcción — se habilita al cerrar el módulo anterior.
