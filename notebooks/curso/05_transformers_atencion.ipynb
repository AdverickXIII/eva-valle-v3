# %% [markdown]
# # Módulo 5 — Transformers y atención
#
# **Objetivo EVA Valle:** Atención temporal y cruzada entre cultivos para predicción multivariante.
#
# 🚧 En construcción — se habilita al cerrar el módulo anterior.
